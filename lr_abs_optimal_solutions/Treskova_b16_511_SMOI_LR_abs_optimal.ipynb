# %% [markdown]
# ### Лабораторная работа №4
# ####  Исследование абсолютно-оптимальных рекуррентных алгоритмов

# %% [markdown]
# Для оценки эффективности абсолютно-оптимальных алгоритмов рассмотрим задачу идентификации параметров линейного регрессионного объекта вида:
# \begin{equation}y(i)=с_{0}+с_{1}u_{1}(i)+...+с_{4}u_{4}(i)+\eta(i)\end{equation}

# %% [markdown]
# Пусть шум измерений $\eta(i)$ имеет распределение Коши:
# \begin{equation*}
# f(\eta)=\frac{1}{\pi s}\frac{1}{(1+(\eta/s)^2)}
# \end{equation*}

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import math

# %%
# параметры объекта 
c0=1.9
c1=-0.9
c2=0.8
c3=0
c4=2.5

# %%
# количество измерений
N=200

# %%
np.random.seed(42)

# %%
# параметр распределения Коши
s=0.1

# %%
Noise=st.cauchy.rvs(loc=0, scale=s, size=N)

# %%
Avg_U1=1
Var_U1=50
Avg_U2=1
Var_U2=50
Avg_U3=1
Var_U3=50
Avg_U4=1
Var_U4=50

# %%
# моделирование входов объекта
U1=np.random.normal(Avg_U1,Var_U1,size=N)
U2=np.random.normal(Avg_U2,Var_U2,size=N)
U3=np.random.normal(Avg_U3,Var_U3,size=N)
U4=np.random.normal(Avg_U4,Var_U4,size=N)

# %%
# моделирование выхода объекта
y=c0+c1*U1+c2*U2+c3*U3+c4*U4+Noise

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# #### Формирование алгоритма идентификации
#
# В зависимости от того, насколько хорошо изучен «объект» идентификации, могут возникнуть следующие ситуации:
#
# 1. Объект изучен хорошо, правильно определена плотность распределения шума, т.е. принятая и реальная плотности распределения совпадают и на основе принятой функции распределения формируется оптимальная функция потерь.
#
#
# 2. Объект изучен плохо. При этом, как правило, считают, что плотность распределения шума соответствует нормальному закону распределения, хотя на самом деле(в данном случаем, см. описание объекта выше) шум имеет распределение Коши. Таким образом, опираясь на ложную гипотезу о нормальном распределении шума, в качестве функции потерь выбирается квадратичная функция.

# %% [markdown]
# Предлагается реализовать абсолютно-оптимальный рекуррентный алгоритм оценивания параметров объекта для каждой из ситуаций. Для   оценки   эффективности использования абсолютно-оптимальных  рекуррентных  алгоритмов  проводилось сравнение сглаженной ошибки оценки параметров объекта,определенных когда объект изучили хорошо и когда плохо, при  различных  значениях  параметра  распределения Коши — s.

# %% [markdown]
# #### В первом случае рекуррентный алгоритм принимает вид:
# \begin{equation}\hat{\vec{c}}(i)=\hat{\vec{c}}(i-1)+Г(i)\frac{2(y(i)-\hat{c}_{0}(i-1)u_{0}(i)-...-\hat{c}_{4}(i-1)u_{4}(i))}{s^2+(y(i)-\hat{c}_{0}(i-1)u_{0}(i)-...-\hat{c}_{4}(i-1)u_{4}(i))^2}\vec{z}(i) \\
# Г(i)=Г(i-1)-\frac{Г(i-1)\vec{z}(i)\vec{z}(i)^TГ(i-1)}{2s^2+\vec{z}^T(i)Г(i-1)\vec{z}(i)} \\
# Г(0)=\lambda I, \lambda=0.1\\
# \hat{\vec{c}}(0)=\vec{c}_{0}\end{equation}

# %%
n = 5
c = np.array(range(N*n), dtype = np.double)
c.shape = (N,n) 
c[0] = [c0,c1,c2,c3,c4]
I = np.eye(n)
l = 0.1
G0 = l*I
print(c)
# Out:
# [[ 1.90e+00 -9.00e-01  8.00e-01  0.00e+00  2.50e+00]
#  [ 5.00e+00  6.00e+00  7.00e+00  8.00e+00  9.00e+00]
#  [ 1.00e+01  1.10e+01  1.20e+01  1.30e+01  1.40e+01]
#  [ 1.50e+01  1.60e+01  1.70e+01  1.80e+01  1.90e+01]
#  [ 2.00e+01  2.10e+01  2.20e+01  2.30e+01  2.40e+01]
#  [ 2.50e+01  2.60e+01  2.70e+01  2.80e+01  2.90e+01]
#  [ 3.00e+01  3.10e+01  3.20e+01  3.30e+01  3.40e+01]
#  [ 3.50e+01  3.60e+01  3.70e+01  3.80e+01  3.90e+01]
#  [ 4.00e+01  4.10e+01  4.20e+01  4.30e+01  4.40e+01]
#  [ 4.50e+01  4.60e+01  4.70e+01  4.80e+01  4.90e+01]
#  [ 5.00e+01  5.10e+01  5.20e+01  5.30e+01  5.40e+01]
#  [ 5.50e+01  5.60e+01  5.70e+01  5.80e+01  5.90e+01]
#  [ 6.00e+01  6.10e+01  6.20e+01  6.30e+01  6.40e+01]
#  [ 6.50e+01  6.60e+01  6.70e+01  6.80e+01  6.90e+01]
#  [ 7.00e+01  7.10e+01  7.20e+01  7.30e+01  7.40e+01]
#  [ 7.50e+01  7.60e+01  7.70e+01  7.80e+01  7.90e+01]
#  [ 8.00e+01  8.10e+01  8.20e+01  8.30e+01  8.40e+01]
#  [ 8.50e+01  8.60e+01  8.70e+01  8.80e+01  8.90e+01]
#  [ 9.00e+01  9.10e+01  9.20e+01  9.30e+01  9.40e+01]
#  [ 9.50e+01  9.60e+01  9.70e+01  9.80e+01  9.90e+01]
#  [ 1.00e+02  1.01e+02  1.02e+02  1.03e+02  1.04e+02]
#  [ 1.05e+02  1.06e+02  1.07e+02  1.08e+02  1.09e+02]
#  [ 1.10e+02  1.11e+02  1.12e+02  1.13e+02  1.14e+02]
#  [ 1.15e+02  1.16e+02  1.17e+02  1.18e+02  1.19e+02]
#  [ 1.20e+02  1.21e+02  1.22e+02  1.23e+02  1.24e+02]
#  [ 1.25e+02  1.26e+02  1.27e+02  1.28e+02  1.29e+02]
#  [ 1.30e+02  1.31e+02  1.32e+02  1.33e+02  1.34e+02]
#  [ 1.35e+02  1.36e+02  1.37e+02  1.38e+02  1.39e+02]
#  [ 1.40e+02  1.41e+02  1.42e+02  1.43e+02  1.44e+02]
#  [ 1.45e+02  1.46e+02  1.47e+02  1.48e+02  1.49e+02]
#  [ 1.50e+02  1.51e+02  1.52e+02  1.53e+02  1.54e+02]
#  [ 1.55e+02  1.56e+02  1.57e+02  1.58e+02  1.59e+02]
#  [ 1.60e+02  1.61e+02  1.62e+02  1.63e+02  1.64e+02]
#  [ 1.65e+02  1.66e+02  1.67e+02  1.68e+02  1.69e+02]
#  [ 1.70e+02  1.71e+02  1.72e+02  1.73e+02  1.74e+02]
#  [ 1.75e+02  1.76e+02  1.77e+02  1.78e+02  1.79e+02]
#  [ 1.80e+02  1.81e+02  1.82e+02  1.83e+02  1.84e+02]
#  [ 1.85e+02  1.86e+02  1.87e+02  1.88e+02  1.89e+02]
#  [ 1.90e+02  1.91e+02  1.92e+02  1.93e+02  1.94e+02]
#  [ 1.95e+02  1.96e+02  1.97e+02  1.98e+02  1.99e+02]
#  [ 2.00e+02  2.01e+02  2.02e+02  2.03e+02  2.04e+02]
#  [ 2.05e+02  2.06e+02  2.07e+02  2.08e+02  2.09e+02]
#  [ 2.10e+02  2.11e+02  2.12e+02  2.13e+02  2.14e+02]
#  [ 2.15e+02  2.16e+02  2.17e+02  2.18e+02  2.19e+02]
#  [ 2.20e+02  2.21e+02  2.22e+02  2.23e+02  2.24e+02]
#  [ 2.25e+02  2.26e+02  2.27e+02  2.28e+02  2.29e+02]
#  [ 2.30e+02  2.31e+02  2.32e+02  2.33e+02  2.34e+02]
#  [ 2.35e+02  2.36e+02  2.37e+02  2.38e+02  2.39e+02]
#  [ 2.40e+02  2.41e+02  2.42e+02  2.43e+02  2.44e+02]
#  [ 2.45e+02  2.46e+02  2.47e+02  2.48e+02  2.49e+02]
#  [ 2.50e+02  2.51e+02  2.52e+02  2.53e+02  2.54e+02]
#  [ 2.55e+02  2.56e+02  2.57e+02  2.58e+02  2.59e+02]
#  [ 2.60e+02  2.61e+02  2.62e+02  2.63e+02  2.64e+02]
#  [ 2.65e+02  2.66e+02  2.67e+02  2.68e+02  2.69e+02]
#  [ 2.70e+02  2.71e+02  2.72e+02  2.73e+02  2.74e+02]
#  [ 2.75e+02  2.76e+02  2.77e+02  2.78e+02  2.79e+02]
#  [ 2.80e+02  2.81e+02  2.82e+02  2.83e+02  2.84e+02]
#  [ 2.85e+02  2.86e+02  2.87e+02  2.88e+02  2.89e+02]
#  [ 2.90e+02  2.91e+02  2.92e+02  2.93e+02  2.94e+02]
#  [ 2.95e+02  2.96e+02  2.97e+02  2.98e+02  2.99e+02]
#  [ 3.00e+02  3.01e+02  3.02e+02  3.03e+02  3.04e+02]
#  [ 3.05e+02  3.06e+02  3.07e+02  3.08e+02  3.09e+02]
#  [ 3.10e+02  3.11e+02  3.12e+02  3.13e+02  3.14e+02]
#  [ 3.15e+02  3.16e+02  3.17e+02  3.18e+02  3.19e+02]
#  [ 3.20e+02  3.21e+02  3.22e+02  3.23e+02  3.24e+02]
#  [ 3.25e+02  3.26e+02  3.27e+02  3.28e+02  3.29e+02]
#  [ 3.30e+02  3.31e+02  3.32e+02  3.33e+02  3.34e+02]
#  [ 3.35e+02  3.36e+02  3.37e+02  3.38e+02  3.39e+02]
#  [ 3.40e+02  3.41e+02  3.42e+02  3.43e+02  3.44e+02]
#  [ 3.45e+02  3.46e+02  3.47e+02  3.48e+02  3.49e+02]
#  [ 3.50e+02  3.51e+02  3.52e+02  3.53e+02  3.54e+02]
#  [ 3.55e+02  3.56e+02  3.57e+02  3.58e+02  3.59e+02]
#  [ 3.60e+02  3.61e+02  3.62e+02  3.63e+02  3.64e+02]
#  [ 3.65e+02  3.66e+02  3.67e+02  3.68e+02  3.69e+02]
#  [ 3.70e+02  3.71e+02  3.72e+02  3.73e+02  3.74e+02]
#  [ 3.75e+02  3.76e+02  3.77e+02  3.78e+02  3.79e+02]
#  [ 3.80e+02  3.81e+02  3.82e+02  3.83e+02  3.84e+02]
#  [ 3.85e+02  3.86e+02  3.87e+02  3.88e+02  3.89e+02]
#  [ 3.90e+02  3.91e+02  3.92e+02  3.93e+02  3.94e+02]
#  [ 3.95e+02  3.96e+02  3.97e+02  3.98e+02  3.99e+02]
#  [ 4.00e+02  4.01e+02  4.02e+02  4.03e+02  4.04e+02]
#  [ 4.05e+02  4.06e+02  4.07e+02  4.08e+02  4.09e+02]
#  [ 4.10e+02  4.11e+02  4.12e+02  4.13e+02  4.14e+02]
#  [ 4.15e+02  4.16e+02  4.17e+02  4.18e+02  4.19e+02]
#  [ 4.20e+02  4.21e+02  4.22e+02  4.23e+02  4.24e+02]
#  [ 4.25e+02  4.26e+02  4.27e+02  4.28e+02  4.29e+02]
#  [ 4.30e+02  4.31e+02  4.32e+02  4.33e+02  4.34e+02]
#  [ 4.35e+02  4.36e+02  4.37e+02  4.38e+02  4.39e+02]
#  [ 4.40e+02  4.41e+02  4.42e+02  4.43e+02  4.44e+02]
#  [ 4.45e+02  4.46e+02  4.47e+02  4.48e+02  4.49e+02]
#  [ 4.50e+02  4.51e+02  4.52e+02  4.53e+02  4.54e+02]
#  [ 4.55e+02  4.56e+02  4.57e+02  4.58e+02  4.59e+02]
#  [ 4.60e+02  4.61e+02  4.62e+02  4.63e+02  4.64e+02]
#  [ 4.65e+02  4.66e+02  4.67e+02  4.68e+02  4.69e+02]
#  [ 4.70e+02  4.71e+02  4.72e+02  4.73e+02  4.74e+02]
#  [ 4.75e+02  4.76e+02  4.77e+02  4.78e+02  4.79e+02]
#  [ 4.80e+02  4.81e+02  4.82e+02  4.83e+02  4.84e+02]
#  [ 4.85e+02  4.86e+02  4.87e+02  4.88e+02  4.89e+02]
#  [ 4.90e+02  4.91e+02  4.92e+02  4.93e+02  4.94e+02]
#  [ 4.95e+02  4.96e+02  4.97e+02  4.98e+02  4.99e+02]
#  [ 5.00e+02  5.01e+02  5.02e+02  5.03e+02  5.04e+02]
#  [ 5.05e+02  5.06e+02  5.07e+02  5.08e+02  5.09e+02]
#  [ 5.10e+02  5.11e+02  5.12e+02  5.13e+02  5.14e+02]
#  [ 5.15e+02  5.16e+02  5.17e+02  5.18e+02  5.19e+02]
#  [ 5.20e+02  5.21e+02  5.22e+02  5.23e+02  5.24e+02]
#  [ 5.25e+02  5.26e+02  5.27e+02  5.28e+02  5.29e+02]
#  [ 5.30e+02  5.31e+02  5.32e+02  5.33e+02  5.34e+02]
#  [ 5.35e+02  5.36e+02  5.37e+02  5.38e+02  5.39e+02]
#  [ 5.40e+02  5.41e+02  5.42e+02  5.43e+02  5.44e+02]
#  [ 5.45e+02  5.46e+02  5.47e+02  5.48e+02  5.49e+02]
#  [ 5.50e+02  5.51e+02  5.52e+02  5.53e+02  5.54e+02]
#  [ 5.55e+02  5.56e+02  5.57e+02  5.58e+02  5.59e+02]
#  [ 5.60e+02  5.61e+02  5.62e+02  5.63e+02  5.64e+02]
#  [ 5.65e+02  5.66e+02  5.67e+02  5.68e+02  5.69e+02]
#  [ 5.70e+02  5.71e+02  5.72e+02  5.73e+02  5.74e+02]
#  [ 5.75e+02  5.76e+02  5.77e+02  5.78e+02  5.79e+02]
#  [ 5.80e+02  5.81e+02  5.82e+02  5.83e+02  5.84e+02]
#  [ 5.85e+02  5.86e+02  5.87e+02  5.88e+02  5.89e+02]
#  [ 5.90e+02  5.91e+02  5.92e+02  5.93e+02  5.94e+02]
#  [ 5.95e+02  5.96e+02  5.97e+02  5.98e+02  5.99e+02]
#  [ 6.00e+02  6.01e+02  6.02e+02  6.03e+02  6.04e+02]
#  [ 6.05e+02  6.06e+02  6.07e+02  6.08e+02  6.09e+02]
#  [ 6.10e+02  6.11e+02  6.12e+02  6.13e+02  6.14e+02]
#  [ 6.15e+02  6.16e+02  6.17e+02  6.18e+02  6.19e+02]
#  [ 6.20e+02  6.21e+02  6.22e+02  6.23e+02  6.24e+02]
#  [ 6.25e+02  6.26e+02  6.27e+02  6.28e+02  6.29e+02]
#  [ 6.30e+02  6.31e+02  6.32e+02  6.33e+02  6.34e+02]
#  [ 6.35e+02  6.36e+02  6.37e+02  6.38e+02  6.39e+02]
#  [ 6.40e+02  6.41e+02  6.42e+02  6.43e+02  6.44e+02]
#  [ 6.45e+02  6.46e+02  6.47e+02  6.48e+02  6.49e+02]
#  [ 6.50e+02  6.51e+02  6.52e+02  6.53e+02  6.54e+02]
#  [ 6.55e+02  6.56e+02  6.57e+02  6.58e+02  6.59e+02]
#  [ 6.60e+02  6.61e+02  6.62e+02  6.63e+02  6.64e+02]
#  [ 6.65e+02  6.66e+02  6.67e+02  6.68e+02  6.69e+02]
#  [ 6.70e+02  6.71e+02  6.72e+02  6.73e+02  6.74e+02]
#  [ 6.75e+02  6.76e+02  6.77e+02  6.78e+02  6.79e+02]
#  [ 6.80e+02  6.81e+02  6.82e+02  6.83e+02  6.84e+02]
#  [ 6.85e+02  6.86e+02  6.87e+02  6.88e+02  6.89e+02]
#  [ 6.90e+02  6.91e+02  6.92e+02  6.93e+02  6.94e+02]
#  [ 6.95e+02  6.96e+02  6.97e+02  6.98e+02  6.99e+02]
#  [ 7.00e+02  7.01e+02  7.02e+02  7.03e+02  7.04e+02]
#  [ 7.05e+02  7.06e+02  7.07e+02  7.08e+02  7.09e+02]
#  [ 7.10e+02  7.11e+02  7.12e+02  7.13e+02  7.14e+02]
#  [ 7.15e+02  7.16e+02  7.17e+02  7.18e+02  7.19e+02]
#  [ 7.20e+02  7.21e+02  7.22e+02  7.23e+02  7.24e+02]
#  [ 7.25e+02  7.26e+02  7.27e+02  7.28e+02  7.29e+02]
#  [ 7.30e+02  7.31e+02  7.32e+02  7.33e+02  7.34e+02]
#  [ 7.35e+02  7.36e+02  7.37e+02  7.38e+02  7.39e+02]
#  [ 7.40e+02  7.41e+02  7.42e+02  7.43e+02  7.44e+02]
#  [ 7.45e+02  7.46e+02  7.47e+02  7.48e+02  7.49e+02]
#  [ 7.50e+02  7.51e+02  7.52e+02  7.53e+02  7.54e+02]
#  [ 7.55e+02  7.56e+02  7.57e+02  7.58e+02  7.59e+02]
#  [ 7.60e+02  7.61e+02  7.62e+02  7.63e+02  7.64e+02]
#  [ 7.65e+02  7.66e+02  7.67e+02  7.68e+02  7.69e+02]
#  [ 7.70e+02  7.71e+02  7.72e+02  7.73e+02  7.74e+02]
#  [ 7.75e+02  7.76e+02  7.77e+02  7.78e+02  7.79e+02]
#  [ 7.80e+02  7.81e+02  7.82e+02  7.83e+02  7.84e+02]
#  [ 7.85e+02  7.86e+02  7.87e+02  7.88e+02  7.89e+02]
#  [ 7.90e+02  7.91e+02  7.92e+02  7.93e+02  7.94e+02]
#  [ 7.95e+02  7.96e+02  7.97e+02  7.98e+02  7.99e+02]
#  [ 8.00e+02  8.01e+02  8.02e+02  8.03e+02  8.04e+02]
#  [ 8.05e+02  8.06e+02  8.07e+02  8.08e+02  8.09e+02]
#  [ 8.10e+02  8.11e+02  8.12e+02  8.13e+02  8.14e+02]
#  [ 8.15e+02  8.16e+02  8.17e+02  8.18e+02  8.19e+02]
#  [ 8.20e+02  8.21e+02  8.22e+02  8.23e+02  8.24e+02]
#  [ 8.25e+02  8.26e+02  8.27e+02  8.28e+02  8.29e+02]
#  [ 8.30e+02  8.31e+02  8.32e+02  8.33e+02  8.34e+02]
#  [ 8.35e+02  8.36e+02  8.37e+02  8.38e+02  8.39e+02]
#  [ 8.40e+02  8.41e+02  8.42e+02  8.43e+02  8.44e+02]
#  [ 8.45e+02  8.46e+02  8.47e+02  8.48e+02  8.49e+02]
#  [ 8.50e+02  8.51e+02  8.52e+02  8.53e+02  8.54e+02]
#  [ 8.55e+02  8.56e+02  8.57e+02  8.58e+02  8.59e+02]
#  [ 8.60e+02  8.61e+02  8.62e+02  8.63e+02  8.64e+02]
#  [ 8.65e+02  8.66e+02  8.67e+02  8.68e+02  8.69e+02]
#  [ 8.70e+02  8.71e+02  8.72e+02  8.73e+02  8.74e+02]
#  [ 8.75e+02  8.76e+02  8.77e+02  8.78e+02  8.79e+02]
#  [ 8.80e+02  8.81e+02  8.82e+02  8.83e+02  8.84e+02]
#  [ 8.85e+02  8.86e+02  8.87e+02  8.88e+02  8.89e+02]
#  [ 8.90e+02  8.91e+02  8.92e+02  8.93e+02  8.94e+02]
#  [ 8.95e+02  8.96e+02  8.97e+02  8.98e+02  8.99e+02]
#  [ 9.00e+02  9.01e+02  9.02e+02  9.03e+02  9.04e+02]
#  [ 9.05e+02  9.06e+02  9.07e+02  9.08e+02  9.09e+02]
#  [ 9.10e+02  9.11e+02  9.12e+02  9.13e+02  9.14e+02]
#  [ 9.15e+02  9.16e+02  9.17e+02  9.18e+02  9.19e+02]
#  [ 9.20e+02  9.21e+02  9.22e+02  9.23e+02  9.24e+02]
#  [ 9.25e+02  9.26e+02  9.27e+02  9.28e+02  9.29e+02]
#  [ 9.30e+02  9.31e+02  9.32e+02  9.33e+02  9.34e+02]
#  [ 9.35e+02  9.36e+02  9.37e+02  9.38e+02  9.39e+02]
#  [ 9.40e+02  9.41e+02  9.42e+02  9.43e+02  9.44e+02]
#  [ 9.45e+02  9.46e+02  9.47e+02  9.48e+02  9.49e+02]
#  [ 9.50e+02  9.51e+02  9.52e+02  9.53e+02  9.54e+02]
#  [ 9.55e+02  9.56e+02  9.57e+02  9.58e+02  9.59e+02]
#  [ 9.60e+02  9.61e+02  9.62e+02  9.63e+02  9.64e+02]
#  [ 9.65e+02  9.66e+02  9.67e+02  9.68e+02  9.69e+02]
#  [ 9.70e+02  9.71e+02  9.72e+02  9.73e+02  9.74e+02]
#  [ 9.75e+02  9.76e+02  9.77e+02  9.78e+02  9.79e+02]
#  [ 9.80e+02  9.81e+02  9.82e+02  9.83e+02  9.84e+02]
#  [ 9.85e+02  9.86e+02  9.87e+02  9.88e+02  9.89e+02]
#  [ 9.90e+02  9.91e+02  9.92e+02  9.93e+02  9.94e+02]
#  [ 9.95e+02  9.96e+02  9.97e+02  9.98e+02  9.99e+02]]

# %%
i = 1
G=G0
while i<N:
    z = np.matrix([1, U1[i], U2[i], U3[i], U4[i]]).T
    G = G - (G*z*z.T*G)/(2*pow(s,2)+z.T*G*z)
    c[i] = c[i-1] + (G*(2*(y[i]-c[i-1][0]-c[i-1][1]*U1[i]-c[i-1][2]*U2[i]-c[i-1][3]*U3[i]-c[i-1][4]*U4[i]))/(pow(s,2)+pow(y[i]-c[i-1][0]-c[i-1][1]*U1[i]-c[i-1][2]*U2[i]-c[i-1][3]*U3[i]-c[i-1][4]*U4[i], 2))*z).T
    i = i + 1
print(c[N-1])
# Out:
# [ 1.70534422 -0.89584963  0.78991434  0.00861077  2.49988536]

# %% [markdown]
# #### Во втором случае рекуррентный алгоритм принимает вид:
# \begin{equation}\hat{\vec{c}}(i)=\hat{\vec{c}}(i-1)+Г(i)\vec{z}(i)(y(i)-\hat{c}_{0}(i-1)u_{0}(i)-...-\hat{c}_{4}(i-1)u_{4}(i)) \\
# Г(i)=Г(i-1)-\frac{Г(i-1)\vec{z}(i)\vec{z}(i)^TГ(i-1)}{1+\vec{z}^T(i)Г(i-1)\vec{z}(i)} \\
# Г(0)=\lambda I , \lambda=0.1    \\
# \hat{\vec{c}}(0)=\vec{c}_{0}\end{equation}

# %%
n=5
c_2 = np.array(range(N*n), dtype = np.double)
c_2.shape = (N,n) 
c_2[0] = [c0,c1,c2,c3,c4]
I = np.eye(n)
l = 0.1
G0 = l*I

# %%
i = 1
G=G0
while i<N:
    z = np.matrix([1, U1[i], U2[i], U3[i], U4[i]]).T
    G = G - (G*z*z.T*G)/(1+z.T*G*z)
    c_2[i] = c_2[i-1] + (G*z*(y[i]-c_2[i-1][0]-c_2[i-1][1]*U1[i]-c_2[i-1][2]*U2[i]-c_2[i-1][3]*U3[i]-c_2[i-1][4]*U4[i])).T
    i = i + 1
print(c_2[N-1])
# Out:
# [ 1.85431274e+00 -9.00730183e-01  8.00344710e-01 -1.61085029e-03
#   2.49996872e+00]

# %% [markdown]
# Сглаженная ошибка оценки вычисляется по формуле:
# \begin{equation*}
# err_{сгл}=\sqrt{\frac{\sum_{j=1}^{10}\sum_{k=0}^4(\hat{c}_{k}(i-j)-c_{k})^2}{10}} ; i=10,11,12...
# \end{equation*}

# %%
error_g = np.array(range(N-10), dtype = np.double)
error_g.shape = (N-10, 1)
error_b = np.array(range(N-10), dtype = np.double)
error_b.shape = (N-10, 1)
cn = [c0,c1,c2,c3,c4]
sqr_g = 0
sqr_b = 0

# %%
for i in range(10,N):
    sqr_g = 0
    sqr_b = 0
    for j in range(1,10):
        for k in range(0,4):
            sqr_g = sqr_g + pow((c[i-j][k]-cn[k]),2)
            sqr_b = sqr_b + pow((c_2[i-j][k]-cn[k]),2)
    error_g[i-10] = math.sqrt(sqr_g/10)
    error_b[i-10] = math.sqrt(sqr_b/10)

plt.plot(error_g,color = 'b')
plt.plot(error_b,color = 'r')
plt.show()
